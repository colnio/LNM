# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as si
import pandas as pd

# %%
data = pd.read_csv("2.csv")
data
# Out:
#          Vsd        9T        8T       12T        7T       13T       11T  \
# 0  -0.079189  0.000018  0.000018  0.000017  0.000019  0.000017  0.000019
# 1  -0.077387  0.000018  0.000018  0.000017  0.000019  0.000017  0.000019
# 2  -0.075586  0.000018  0.000016  0.000017  0.000017  0.000016  0.000018
# 3  -0.073784  0.000016  0.000016  0.000017  0.000017  0.000018  0.000018
# 4  -0.071982  0.000017  0.000019  0.000019  0.000018  0.000017  0.000016
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.091982  0.000020  0.000019  0.000021  0.000017  0.000020  0.000020
# 96  0.093784  0.000019  0.000020  0.000017  0.000024  0.000019  0.000021
# 97  0.095586  0.000018  0.000019  0.000019  0.000022  0.000019  0.000021
# 98  0.097387  0.000022  0.000020  0.000022  0.000018  0.000022  0.000015
# 99  0.099189  0.000020  0.000019  0.000021  0.000016  0.000015  0.000020
#
#          10T       14T       15T        5T       16T        6T
# ...

# %%
x = [float(i[:-1:]) for i in data.keys()[1::]]
x.sort()
x = np.array(x)
y = np.array(data['Vsd']) * 1000

# %%
data = data.drop(columns=['Vsd'])

# %%
data = data.reindex(sorted(data.columns, key=lambda x : float(x[:-1:])), axis=1)

# %%
extent = [x[0], x[-1], y[0], y[-1]]

# %%
plt.figure(figsize=(15, 15))

plt.clf()
plt.imshow(data.values, extent=extent, origin='lower', interpolation='bilinear', aspect='auto')
cb = plt.colorbar()
cb.set_label('dI/dV', rotation=270)
plt.title("dI/dV vs (Vsd, B)")
plt.rcParams.update({'font.size': 25})
plt.xlabel('Field, T')
plt.ylabel('Vsd, mV')
# plt.savefig("f.png", dpi=400)
plt.show()
